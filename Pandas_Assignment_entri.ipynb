# %% [markdown]
# # PANDAS ASSIGNMENT

# %% [markdown]
# 1. Create a Pandas series with the following data: {'apples': 3, 'bananas': 2, 'oranges': 1}. Then, add a new item to the series with the key 'pears' and the value 4.

# %%
import pandas as pd

# %%
fruits=pd.Series({'Apples':3,'Bananas':2, 'Oranges':1})
fruits
# Out:
# Apples     3
# Bananas    2
# Oranges    1
# dtype: int64

# %%
fruits['Pears']=4
fruits
# Out:
# Apples     3
# Bananas    2
# Oranges    1
# Pears      4
# dtype: int64

# %% [markdown]
# 2. Create a dataframe with the following columns: name, age, and gender. The dataframe should have 10 rows of data.

# %%
df_per_details=pd.DataFrame({
    'Name':['Amar','Binoy', 'Cini', 'Deepu','Emily', 'Fayaz', 'Greeshma', 'Harish','Indu','Jack'],
    'Age':[22,65,86,74,19,9,12,30,44,93],
    'Gender':['M','F','F','M','F','M','M','F','M','F']
    })
df_per_details
# Out:
#        Name  Age Gender
# 0      Amar   22      M
# 1     Binoy   65      F
# 2      Cini   86      F
# 3     Deepu   74      M
# 4     Emily   19      F
# 5     Fayaz    9      M
# 6  Greeshma   12      M
# 7    Harish   30      F
# 8      Indu   44      M
# 9      Jack   93      F

# %% [markdown]
# 3. Add a new column to the data frame created in question 1, called occupation. The values for this column should be Programmer, Manager, and Analyst, corresponding to the rows in the dataframe.

# %%
df_per_details['Occupation']=['Programmer', 'Manager', 'Analyst','Programmer', 'Manager', 'Analyst',
                              'Programmer', 'Manager', 'Analyst','Manager']
df_per_details
# Out:
#        Name  Age Gender  Occupation
# 0      Amar   22      M  Programmer
# 1     Binoy   65      F     Manager
# 2      Cini   86      F     Analyst
# 3     Deepu   74      M  Programmer
# 4     Emily   19      F     Manager
# 5     Fayaz    9      M     Analyst
# 6  Greeshma   12      M  Programmer
# 7    Harish   30      F     Manager
# 8      Indu   44      M     Analyst
# 9      Jack   93      F     Manager

# %% [markdown]
# 4. Select the rows of the dataframe where the age is greater than or equal to 30.

# %%
df_per_details[df_per_details['Age']>=30]
# Out:
#      Name  Age Gender  Occupation
# 1   Binoy   65      F     Manager
# 2    Cini   86      F     Analyst
# 3   Deepu   74      M  Programmer
# 7  Harish   30      F     Manager
# 8    Indu   44      M     Analyst
# 9    Jack   93      F     Manager

# %% [markdown]
# 5. Convert this dataframe to a csv file and read that csv file, finally display the contents.

# %%
df_per_details.to_csv('Personal_Details.csv')

# %%
df1=pd.read_csv('Personal_Details.csv')
df1
# Out:
#    Unnamed: 0      Name  Age Gender  Occupation
# 0           0      Amar   22      M  Programmer
# 1           1     Binoy   65      F     Manager
# 2           2      Cini   86      F     Analyst
# 3           3     Deepu   74      M  Programmer
# 4           4     Emily   19      F     Manager
# 5           5     Fayaz    9      M     Analyst
# 6           6  Greeshma   12      M  Programmer
# 7           7    Harish   30      F     Manager
# 8           8      Indu   44      M     Analyst
# 9           9      Jack   93      F     Manager
